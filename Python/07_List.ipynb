# %% [markdown]
# List items are ordered, changeable, and allow duplicate values.
#
# List items are indexed, the first item has index [0], the second item has index [1] etc.

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]

# %% [markdown]
# thislist[0]

# %%
thislist[0]
# print(thislist[1::2])
# Out:
# 'apple'

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:2] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)
# Out:
# ['apple', 'watermelon']

# %% [markdown]
# To insert a list item at a specified index, use the insert() method.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(7, "watermelon")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'watermelon']

# %%
thislist[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1688676722.py in <cell line: 0>()
# ----> 1 thislist[7]
#
# IndexError: list index out of range

# %% [markdown]
# To add an item to the end of the list, use the append() method:

# %%
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)

# %% [markdown]
# To append elements from another list to the current list, use the extend() method.

# %%
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)
thislist['1']
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1084397290.py in <cell line: 0>()
#       3 thislist.extend(tropical)
#       4 print(thislist)
# ----> 5 thislist['1']
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# The extend() method does not have to append lists, you can add any iterable object (tuples, sets, dictionaries etc.).

# %%
thislist = ["apple", "banana", "cherry"]
thistuple = ("kiwi", "orange")
thislist.extend(thistuple)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'orange']

# %%
data = [10,20,30]
value = (int(input("enter the value: ")))
index = int(input("enter the index: "))
data.insert(index, value)
print(data)
# Out:
# enter the value: 40
# enter the index: 3
# [10, 20, 30, 40]

# %% [markdown]
# The remove() method removes the specified item.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# The pop() method removes the specified index.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
# The del keyword also removes the specified index:
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)
x =3
del x
print(x)
# Out:
# ['banana', 'cherry']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3609828258.py in <cell line: 0>()
#       5 x =3
#       6 del x
# ----> 7 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# The clear() method empties the list.
#
# The list still remains, but it has no content.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %% [markdown]
# looping

# %%
thislist = ["apple", "banana", "cherry"]
for x in thislist:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
num = [10,20,30,40]
total=0
for x in num:
  print(x)
  total += x
  # print(total)
# Out:
# 10
# 20
# 30
# 40

# %%
thislist = ["apple", "banana", "cherry"]
len(thislist)
for i in range(len(thislist)):
  # print(i)
  print(i,thislist[i])
# Out:
# 0 apple
# 1 banana
# 2 cherry

# %%
list =[1,2,3,4]
sqlist =[]
for x in range(len(list)):
  sqlist.append(list[x]*list[x])

print(sqlist)
# Out:
# [1, 4, 9, 16]

# %%
thislist = ["apple", "banana", "cherry"]
i = 0
while i < len(thislist):
  print(thislist[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
[(len((x))) for x in thislist]
# Out:
# [5, 6, 6]

# %% [markdown]
# List Comprehension
#
# List comprehension offers a shorter syntax when you want to create a new list based on the values of an existing list.
# newlist = [expression for item in iterable if condition == True]

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)

print(newlist)

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]

newlist = [x for x in fruits if "a" in x]

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
# You can use the range() function to create an iterable:
newlist = [x for x in range(10)]

# %%
newlist = ['hello' for x in fruits]

# %%
newlist
# Out:
# ['hello', 'hello', 'hello', 'hello', 'hello']

# %%
newlist = [x if x != "banana" else "orange" for x in fruits]
# If x is not 'banana', use x. Otherwise, use 'orange'.”

# %% [markdown]
# ... if <condition> at the end is a filter (it can’t have else)
#
# ... if <condition> else ... is a conditional expression (it must come before the for)

# %%
newliat =[x for x in fruits if x!="banana"else "orange"]
print(newliat)
# Out:
#   File "/tmp/ipython-input-531394169.py", line 1
#     newliat =[x for x in fruits if x!="banana"else "orange"]
#                                               ^
# SyntaxError: invalid syntax

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort()
print(thislist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort()
print(thislist)
# Out:
# [23, 50, 65, 82, 100]

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort(reverse = True)
print(thislist)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort(reverse = True)
print(thislist)
# Out:
# [100, 82, 65, 50, 23]

# %% [markdown]
# You can also customize your own function by using the keyword argument key = function.

# %%
def myfunc(n):
  return abs(n - 50)

thislist = [100, 50, 65, 82, 23]
thislist.sort(key = myfunc)
print(thislist)

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort()
print(thislist)
# Out:
# ['Kiwi', 'Orange', 'banana', 'cherry']

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.reverse()
print(thislist)
# Out:
# ['cherry', 'Kiwi', 'Orange', 'banana']

# %%
thislist[-2]
# Out:
# 'Orange'

# %%
num ={1,2,2,3,4,4}
num
# Out:
# {1, 2, 3, 4}

# %%
num[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2129859239.py in <cell line: 0>()
# ----> 1 num[1]
#
# TypeError: 'set' object is not subscriptable

# %%
Tuple=  (1,2,3,4,3)

# %%
Tuple[1
      ]
# Out:
# 2

# %%
Tuple[1]= 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2884114869.py in <cell line: 0>()
# ----> 1 Tuple[1]= 3
#
# TypeError: 'tuple' object does not support item assignment

# %%
numset ={ 10,20,50,90,4}

# %%
numset
# Out:
# {4, 10, 20, 50, 90}

# %%
mylist =[10,20,90,4]
mylist
# Out:
# [10, 20, 90, 4]
